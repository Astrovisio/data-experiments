# %%
import yt

# %%
ds = yt.load(".data/testdata/gadget3/snap_028_z000p000.0.hdf5")
# Out:
# yt : [INFO     ] 2025-01-24 16:00:35,994 Parameters: current_time              = 4.359836051529778e+17 s
# yt : [INFO     ] 2025-01-24 16:00:35,995 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-01-24 16:00:35,996 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-01-24 16:00:35,997 Parameters: domain_right_edge         = [33.885 33.885 33.885]
# yt : [INFO     ] 2025-01-24 16:00:35,998 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2025-01-24 16:00:35,999 Parameters: current_redshift          = 4.440892098500626e-16
# yt : [INFO     ] 2025-01-24 16:00:35,999 Parameters: omega_lambda              = 0.6844
# yt : [INFO     ] 2025-01-24 16:00:36,000 Parameters: omega_matter              = 0.3156
# yt : [INFO     ] 2025-01-24 16:00:36,001 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2025-01-24 16:00:36,002 Parameters: hubble_constant           = 0.6727

# %%
ds.field_list
# Out:
# yt : [WARNING  ] 2025-01-24 16:00:37,479 Failed to load '/home/tmassagl/development/pynbody/testdata/gadget3/snap_028_z000p000.1.hdf5' (missing file or directory)
# yt : [WARNING  ] 2025-01-24 16:00:37,481 Failed to load '/home/tmassagl/development/pynbody/testdata/gadget3/snap_028_z000p000.2.hdf5' (missing file or directory)
# yt : [WARNING  ] 2025-01-24 16:00:37,483 Failed to load '/home/tmassagl/development/pynbody/testdata/gadget3/snap_028_z000p000.3.hdf5' (missing file or directory)
# yt : [WARNING  ] 2025-01-24 16:00:37,484 Failed to load '/home/tmassagl/development/pynbody/testdata/gadget3/snap_028_z000p000.4.hdf5' (missing file or directory)
# yt : [WARNING  ] 2025-01-24 16:00:37,485 Failed to load '/home/tmassagl/development/pynbody/testdata/gadget3/snap_028_z000p000.5.hdf5' (missing file or directory)
# yt : [WARNING  ] 2025-01-24 16:00:37,486 Failed to load '/home/tmassagl/development/pynbody/testdata/gadget3/snap_028_z000p000.6.hdf5' (missing file or directory)
# ...

# %%
p = yt.ParticlePlot(ds, "Coordinates", "Masses")
p.show()
# Out:
# yt : [INFO     ] 2025-01-24 10:25:05,682 xlim = 24.750000 25.250000
# yt : [INFO     ] 2025-01-24 10:25:05,683 ylim = 24.750000 25.250000
# yt : [INFO     ] 2025-01-24 10:25:05,685 xlim = 24.750000 25.250000
# yt : [INFO     ] 2025-01-24 10:25:05,686 ylim = 24.750000 25.250000
# yt : [INFO     ] 2025-01-24 10:25:05,689 Splatting (('all', 'particle_mass')) onto a 800 by 800 mesh using method 'ngp'
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
